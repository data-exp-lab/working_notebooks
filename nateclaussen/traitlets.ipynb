# %%
import yt

# %%
cd home/nclauss2/Desktop/working_notebooks/
# Out:
# [Errno 2] No such file or directory: 'home/nclauss2/Desktop/working_notebooks/'
# /home/nclauss2/Desktop/working_notebooks/nateclaussen

# %%
ds = yt.load("../IsolatedGalaxy/galaxy0030/galaxy0030")
# Out:
# yt : [INFO     ] 2018-09-07 12:40:36,015 Parameters: current_time              = 0.00600002000283
# yt : [INFO     ] 2018-09-07 12:40:36,020 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2018-09-07 12:40:36,024 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-09-07 12:40:36,026 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-09-07 12:40:36,027 Parameters: cosmological_simulation   = 0.0

# %%
p = yt.ProfilePlot(ds.all_data(), 'Density', 'Temperature')
# Out:
# Parsing Hierarchy : 100%|██████████| 173/173 [00:00<00:00, 15215.55it/s]
# yt : [INFO     ] 2018-09-07 12:40:36,435 Gathering a field list (this may take a moment.)
# /home/nclauss2/.local/lib/python2.7/site-packages/yt/units/yt_array.py:978: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   ret = super(YTArray, self).__getitem__(item)
# /home/nclauss2/.local/lib/python2.7/site-packages/yt/fields/fluid_fields.py:201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   new_field[slice_3d] = f

# %%
p.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
# ?yt.ProfilePlot.save
# Out:
# Signature: yt.ProfilePlot.save(*args, **kwargs)
# Docstring:
# Saves a 1d profile plot.
#
# Parameters
# ----------
# name : str
#     The output file keyword.
# suffix : string
#     Specify the image type by its suffix. If not specified, the output
#     type will be inferred from the filename. Defaults to PNG.
# mpl_kwargs : dict
#     A dict of keyword arguments to be passed to matplotlib.
# File:      ~/.local/lib/python2.7/site-packages/yt/visualization/plot_container.py
# Type:      instancemethod

# %%
p.save()
# Out:
# yt : [INFO     ] 2018-09-07 12:44:26,972 Saving galaxy0030_1d-Profile_Density_Temperature.png
# yt : [INFO     ] 2018-09-07 12:44:26,974 Saving plot galaxy0030_1d-Profile_Density_Temperature.png
# ['galaxy0030_1d-Profile_Density_Temperature.png']
