# %%
import yt

# %%
ls
# Out:
# nclauss2/  syscore/

# %%
cd Desktop/working_notebooks
# Out:
# [Errno 2] No such file or directory: 'Desktop/working_notebooks'
# /home

# %%
pwd
# Out:
# '/home'

# %%
cd nclauss2/Desktop/working_notebooks
# Out:
# [Errno 2] No such file or directory: 'nclauss2/Desktop/working_notebooks'
# /home/nclauss2

# %%
pwd
# Out:
# '/home/nclauss2'

# %%
ls
# Out:
#  anaconda3/                   Documents/   Public/             Untitled.ipynb
#  bin/                         Downloads/   snap/               Videos/
# 'Calibre Library'/            ltunify/     Templates/
# 'Chaos - James Gleick.epub'   Music/       tmux/
#  Desktop/                     Pictures/    Unity-2018.2.0f2/

# %%
cd Desktop
# Out:
# [Errno 2] No such file or directory: 'Desktop'
# /home/nclauss2/Desktop

# %%
cd working_notebooks
# Out:
# /home/nclauss2/Desktop/working_notebooks

# %%
ds = yt.load("IsolatedGalaxy/galaxy0030/galaxy0030")
# Out:
# yt : [INFO     ] 2018-08-14 14:38:44,459 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2018-08-14 14:38:44,460 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2018-08-14 14:38:44,461 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-08-14 14:38:44,463 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-08-14 14:38:44,464 Parameters: cosmological_simulation   = 0.0

# %%
p = yt.ProfilePlot(ds.all_data(), "density", ["temperature", "velocity_x"])
# Out:
# Parsing Hierarchy : 100%|██████████| 173/173 [00:00<00:00, 38264.76it/s]
# yt : [INFO     ] 2018-08-14 15:22:32,920 Gathering a field list (this may take a moment.)

# %%
p.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br><img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
yt.lo
